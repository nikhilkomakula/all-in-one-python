# %% [markdown]
# # Gradient Descent (Univariate)

# %% [markdown]
# Let's start by implementing gradient descent with a fixed learning rate in Python.
#
#
# We will use the following cost function:
#
# f(x) = (x - 5) ** 2 + 20

# %% [markdown]
# ## Plot the function using randomly generated values

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the function f(x)
def f(x):
    return (x - 5) ** 2 + 20

# Create an array of x values
x = np.linspace(-10, 20, 1000)

# Evaluate f(x) for each value of x
y = f(x)

# Plot f(x) versus x
plt.plot(x, y)

# Add labels and a title to the plot
plt.xlabel('x')
plt.ylabel('f(x)')
plt.title('Plot of f(x) versus x')

# Display the plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define the cost function
def cost_function(x):
    return (x - 5) ** 2 + 20

# Define the gradient of the cost function
def cost_function_gradient(x):
    return 2 * (x - 5)

# Initialize the model parameter with a random value
x = np.random.randn()

# Set the learning rate
learning_rate = 0.1

# Set the maximum number of iterations
num_iter = 100

# Initialize the list to store the cost values
cost_values = []

# Initialize the list to store the x values
x_values = [x]

# Iterate until convergence or total number of iterations
for i in range(num_iter):
    # Calculate the cost and gradient at the current parameter
    cost = cost_function(x)
    gradient = cost_function_gradient(x)

    # Update the parameter
    x = x - learning_rate * gradient

    # Store the cost value
    cost_values.append(cost)
    
    # Store the x value
    x_values.append(x)

    # Print the progress
    if i % 10 == 0:
        print("Iteration {}: x = {}, cost = {}".format(i, x, cost))

# Plot the cost values
plt.plot(cost_values)
plt.xlabel("Iterations")
plt.ylabel("Cost")
plt.show()
# Out:
# Iteration 0: x = 2.759509872274548, cost = 27.84343126943002
# Iteration 10: x = 4.759429204360208, cost = 20.090428605804316
# Iteration 20: x = 4.97416890750886, cost = 20.001042570842635
# Iteration 30: x = 4.997226407563265, cost = 20.000012020023444
# Iteration 40: x = 4.999702187779795, cost = 20.000000138581434
# Iteration 50: x = 4.999968022656347, cost = 20.000000001597734
# Iteration 60: x = 4.99999656645887, cost = 20.00000000001842
# Iteration 70: x = 4.999999631326328, cost = 20.000000000000213
# Iteration 80: x = 4.999999960413966, cost = 20.000000000000004
# Iteration 90: x = 4.999999995749482, cost = 20.0

# %% [markdown]
# ## Plot the iterations

# %%
# Create an array of x values
x = np.linspace(-2, 15, 100)

# Evaluate f(x) for each value of x
y = cost_function(x)

# Plot f(x) versus x
plt.plot(x, y)

# Plot the gradient descent iterations
for i in range(len(x_values) - 1):
    x1 = x_values[i]
    y1 = cost_function(x1)
    x2 = x_values[i + 1]
    y2 = cost_function(x2)
    plt.plot([x1, x2], [y1, y2], 'ro-')
    plt.text(x1, y1 + 0.5, round(y1, 2))

# Label the final cost value
x_final = x_values[-1]
y_final = cost_function(x_final)
plt.text(x_final, y_final + 0.5, round(y_final, 2))

# Add labels and a title to the plot
plt.xlabel('x')
plt.ylabel('cost_function(x)')
plt.title('Gradient descent iterations on f(x)')

# Display the plot
plt.show()
